# %% [markdown]
# # last session Assignment

# %% [markdown]
# user enter words and replace certain characters with *** (without libraries)

# %%
x = input("enter what you want")
x.replace("h", "*")
x.replace("s", "*")
# Out:
# 'knjknbjbhjcdgf*x'

# %% [markdown]
# input list of number and get the mathematical range (without libraries)

# %%
x = []
c = int(input("enter the number"))
x.append(c)
v = int(input("enter the number"))
x.append(v)

b = int(input("enter the number"))
x.append(b)

max_num= max(x)
min_num = min(x)

print(max_num- min_num)
# Out:
# 3

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

img = mpimg.imread('jjjj.png')


plt.imshow(img)
plt.title('Image')
plt.axis('off') # remove axis
plt.show()

# %% [markdown]
# # If condition /// else/// elif

# %%
x = 19
y=190

if x > y :
    print("x is greater than y")
elif x == y :
    print("x = y")
else:
    print("y is greater")
# Out:
# y is greater

# %% [markdown]
# # AND //// OR //// NOT

# %%
x = 2
y = 3 
a=5

if a == x+y:
    print(True)
# Out:
# True

# %% [markdown]
# # indentation error

# %%
a = 33
b = 200
if b > a:
    print("b is greater than a") # you will get an error
# Out:
# b is greater than a

# %%
img = mpimg.imread('Screenshot 2023-09-09 172428.png')


plt.imshow(img)
plt.title('Image')
plt.axis('off') # remove axis
plt.show()

# %% [markdown]
# # Nested If

# %%
x = 2

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
else:
  print("ddd")
# Out:
# ddd

# %% [markdown]
# if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.

# %%
a = 33
b = 200

if b > a:
  pass

# %%
x = [0,1,2,3]

# %% [markdown]
# # Dictionary

# %% [markdown]
# ordered*, changeable and do not allow duplicates.
#
#
# changeable, meaning that we can change, add or remove items after the dictionary has been created.
#
#
# ordered, it means that the items have a defined order, and that order will not change.

# %%
car= {
    "color":"read",
    "number of wheels":[1,2, "ffffff"],
    "kind": " mercedes",
}

car
# Out:
# {'color': 'read', 'number of wheels': [1, 2, 'ffffff'], 'kind': ' mercedes'}

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print(thisdict["colors"])


# dictionaries have len
# Out:
# ['red', 'white', 'blue']

# %% [markdown]
# # nested dictioanries

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily["child2"]["name"])
# Out:
# Tobias

# %% [markdown]
# # dictionaries methods

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

car.clear()

print(car)
# Out:
# {}

# %%
x = ('key1', 'key2', 'key3')
y = 1

thisdict = dict.fromkeys(x, y) # make dictionaries from X and Y

print(thisdict)
# Out:
# {'key1': 1, 'key2': 1, 'key3': 1}

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = car.get("model")

print(x)
# Out:
# Mustang

# %% [markdown]
# # SETS

# %% [markdown]
# Set items are unordered, unchangeable, and do not allow duplicate values
#
# A set is a collection which is unordered, unchangeable*, and unindexed
#
# Note: Set items are unchangeable, but you can remove items and add new items.

# %%
y = set()
print(type(y))
# Out:
# <class 'set'>

# %%
x = {}
print(type(x))

# %% [markdown]
# # Set methods

# %%
fruits = {"apple", "banana", "cherry"}

fruits.add("orange")

print(fruits)
# Out:
# {'orange', 'cherry', 'apple', 'banana'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.difference(y)

print(z)
# Out:
# {'cherry', 'banana'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.intersection(y)

print(z)
# Out:
# {'apple'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "facebook"}

z = x.isdisjoint(y)

print(z)
# Out:
# True

# %% [markdown]
# # Tuples

# %% [markdown]
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
#
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
tuple1 = ("abc", 34, True, 40, "male")

print(thistuple)

print(tuple1)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')
# ('abc', 34, True, 40, 'male')

# %% [markdown]
# # Methods

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.count(5) # returns the number of times a specified value appears in the tuple

print(x)
# Out:
# 2

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(8)

print(x)
# Out:
# 3

# %%
x = []
c = int(input("enter the number"))
x.append(c)
v = int(input("enter the number"))
x.append(v)

b = int(input("enter the number"))
x.append(b)

print(max(x))
# Out:
# 10
